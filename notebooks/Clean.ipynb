# %%
# importing of libraries
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import os,sys
sys.path.append(os.path.abspath(os.path.join('..')))
from scripts.clean import Clean
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams["figure.figsize"] = (12, 8)
pd.set_option('display.max_columns', None)

# %%
missing_values = ["n/a", "na", "undefined"]
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
store = pd.read_csv("../data/store.csv",na_values=missing_values)
# Out:
# /tmp/ipykernel_68568/2425854849.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv("../data/train.csv")

# %%
# begin cleaning the train dataset
clean_df = Clean(train)

# %%
clean_df.merge_df(store,'Store')
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a             1270.000
# 1                  0              1         a          a              570.000
# 2                  0              1         a          a            14130.000
# 3                  0              1         c          c              620.000
# 4                  0              1         a          a            29910.000
# ...              ...            ...       ...        ...                  ...
# 1017204            a              1         a          a             1900.000
# 1017205            a              1         c          c             1880.000
# 1017206            a              1         a          c             9260.000
# 1017207            a              1         a          c              870.000
# 1017208            a              1         d          c             5350.000
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.000                  2008.000       0
# 1                           11.000                  2007.000       1
# 2                           12.000                  2006.000       1
# 3                            9.000                  2009.000       0
# 4                            4.000                  2015.000       0
# ...                            ...                       ...     ...
# 1017204                      6.000                  2014.000       1
# 1017205                      4.000                  2006.000       0
# 1017206                        NaN                       NaN       0
# 1017207                        NaN                       NaN       0
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                    NaN              NaN               NaN
# 1                 13.000         2010.000   Jan,Apr,Jul,Oct
# 2                 14.000         2011.000   Jan,Apr,Jul,Oct
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 1017204           31.000         2013.000   Jan,Apr,Jul,Oct
# 1017205              NaN              NaN               NaN
# 1017206              NaN              NaN               NaN
# 1017207              NaN              NaN               NaN
# 1017208           22.000         2012.000  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %%
clean_df.drop_missing_values()

# %%
clean_df.fix_outliers()
# Out:
#           Store  DayOfWeek        Date     Sales  Customers  Open  Promo  \
# 1         2.000      5.000  2015-07-31  6064.000    625.000 1.000  1.000
# 2         3.000      5.000  2015-07-31  8314.000    821.000 1.000  1.000
# 10       11.000      5.000  2015-07-31 10457.000    557.000 1.000  1.000
# 13       14.000      5.000  2015-07-31  6544.000    710.000 1.000  1.000
# 14       15.000      5.000  2015-07-31  9191.000    766.000 1.000  1.000
# ...         ...        ...         ...       ...        ...   ...    ...
# 1017198 563.000      2.000  2013-01-01     0.000      0.000 0.000  0.000
# 1017199 563.000      2.000  2013-01-01     0.000      0.000 0.000  0.000
# 1017200 563.000      2.000  2013-01-01     0.000      0.000 0.000  0.000
# 1017202 563.000      2.000  2013-01-01     0.000      0.000 0.000  0.000
# 1017204 563.000      2.000  2013-01-01     0.000      0.000 0.000  0.000
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 1                  0          1.000         a          a              570.000
# 2                  0          1.000         a          a            14130.000
# 10                 0          1.000         a          c              960.000
# 13                 0          1.000         a          a             1300.000
# 14                 0          1.000         d          c             4110.000
# ...              ...            ...       ...        ...                  ...
# 1017198            a          1.000         c          c              330.000
# 1017199            a          1.000         a          c             5330.000
# 1017200            a          1.000         a          a             1400.000
# 1017202            a          1.000         c          a             3490.000
# 1017204            a          1.000         a          a             1900.000
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 1                           11.000                  2007.000   1.000
# 2                           12.000                  2006.000   1.000
# 10                          11.000                  2011.000   1.000
# 13                           3.000                  2014.000   1.000
# 14                           3.000                  2010.000   1.000
# ...                            ...                       ...     ...
# 1017198                     11.000                  2008.000   1.000
# 1017199                      9.000                  2011.000   1.000
# 1017200                      6.000                  2012.000   1.000
# 1017202                      4.000                  2011.000   1.000
# 1017204                      6.000                  2014.000   1.000
#
#          Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 1                 13.000         2010.000  Jan,Apr,Jul,Oct
# 2                 14.000         2011.000  Jan,Apr,Jul,Oct
# 10                 1.000         2012.000  Jan,Apr,Jul,Oct
# 13                40.000         2011.000  Jan,Apr,Jul,Oct
# 14                14.000         2011.000  Jan,Apr,Jul,Oct
# ...                  ...              ...              ...
# 1017198            5.000         2013.000  Feb,May,Aug,Nov
# 1017199           31.000         2013.000  Jan,Apr,Jul,Oct
# 1017200           13.000         2010.000  Jan,Apr,Jul,Oct
# 1017202           22.000         2012.000  Jan,Apr,Jul,Oct
# 1017204           31.000         2013.000  Jan,Apr,Jul,Oct
#
# [324326 rows x 18 columns]

# %%
clean_df.remove_unnamed_cols()

# %%
clean_df.save(name="../data/training.csv")

# %%
clean_df = Clean(test)

# %%
clean_df.merge_df(store,'Store')
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17 1.000      1            0
# 1          2      3          4  2015-09-17 1.000      1            0
# 2          3      7          4  2015-09-17 1.000      1            0
# 3          4      8          4  2015-09-17 1.000      1            0
# 4          5      9          4  2015-09-17 1.000      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01 1.000      0            0
# 41084  41085   1112          6  2015-08-01 1.000      0            0
# 41085  41086   1113          6  2015-08-01 1.000      0            0
# 41086  41087   1114          6  2015-08-01 1.000      0            0
# 41087  41088   1115          6  2015-08-01 1.000      0            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0         c          a             1270.000
# 1                  0         a          a            14130.000
# 2                  0         a          c            24000.000
# 3                  0         a          a             7520.000
# 4                  0         a          c             2030.000
# ...              ...       ...        ...                  ...
# 41083              0         a          a             1900.000
# 41084              0         c          c             1880.000
# 41085              0         a          c             9260.000
# 41086              0         a          c              870.000
# 41087              1         d          c             5350.000
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                          9.000                  2008.000       0
# 1                         12.000                  2006.000       1
# 2                          4.000                  2013.000       0
# 3                         10.000                  2014.000       0
# 4                          8.000                  2000.000       0
# ...                          ...                       ...     ...
# 41083                      6.000                  2014.000       1
# 41084                      4.000                  2006.000       0
# 41085                        NaN                       NaN       0
# 41086                        NaN                       NaN       0
# 41087                        NaN                       NaN       1
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                  NaN              NaN               NaN
# 1               14.000         2011.000   Jan,Apr,Jul,Oct
# 2                  NaN              NaN               NaN
# 3                  NaN              NaN               NaN
# 4                  NaN              NaN               NaN
# ...                ...              ...               ...
# 41083           31.000         2013.000   Jan,Apr,Jul,Oct
# 41084              NaN              NaN               NaN
# 41085              NaN              NaN               NaN
# 41086              NaN              NaN               NaN
# 41087           22.000         2012.000  Mar,Jun,Sept,Dec
#
# [41088 rows x 17 columns]

# %%
clean_df.drop_missing_values()

# %%
clean_df.fix_outliers()
# Out:
#              Id   Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 1         2.000   3.000      4.000  2015-09-17 1.000  1.000            0
# 6         7.000  11.000      4.000  2015-09-17 1.000  1.000            0
# 9        10.000  14.000      4.000  2015-09-17 1.000  1.000            0
# 10       11.000  15.000      4.000  2015-09-17 1.000  1.000            0
# 13       14.000  20.000      4.000  2015-09-17 1.000  1.000            0
# ...         ...     ...        ...         ...   ...    ...          ...
# 41079 20543.000 590.000      6.000  2015-08-01 1.000  0.000            0
# 41080 20543.000 590.000      6.000  2015-08-01 1.000  0.000            0
# 41081 20543.000 590.000      6.000  2015-08-01 1.000  0.000            0
# 41082 20543.000 590.000      6.000  2015-08-01 1.000  0.000            0
# 41083 20543.000 590.000      6.000  2015-08-01 1.000  0.000            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 1              0.000         a          a            14130.000
# 6              0.000         a          c              960.000
# 9              0.000         a          a             1300.000
# 10             0.000         d          c             4110.000
# 13             0.000         d          a             2340.000
# ...              ...       ...        ...                  ...
# 41079          0.000         c          c              330.000
# 41080          0.000         a          c             5330.000
# 41081          0.000         a          a             1400.000
# 41082          0.000         c          a             3490.000
# 41083          0.000         a          a             1900.000
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 1                         12.000                  2006.000   1.000
# 6                         11.000                  2011.000   1.000
# 9                          3.000                  2014.000   1.000
# 10                         3.000                  2010.000   1.000
# 13                         5.000                  2009.000   1.000
# ...                          ...                       ...     ...
# 41079                     11.000                  2008.000   1.000
# 41080                      9.000                  2011.000   1.000
# 41081                      6.000                  2012.000   1.000
# 41082                      4.000                  2011.000   1.000
# 41083                      6.000                  2014.000   1.000
#
#        Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 1               14.000         2011.000  Jan,Apr,Jul,Oct
# 6                1.000         2012.000  Jan,Apr,Jul,Oct
# 9               40.000         2011.000  Jan,Apr,Jul,Oct
# 10              14.000         2011.000  Jan,Apr,Jul,Oct
# 13              40.000         2014.000  Jan,Apr,Jul,Oct
# ...                ...              ...              ...
# 41079            5.000         2013.000  Feb,May,Aug,Nov
# 41080           31.000         2013.000  Jan,Apr,Jul,Oct
# 41081           13.000         2010.000  Jan,Apr,Jul,Oct
# 41082           22.000         2012.000  Jan,Apr,Jul,Oct
# 41083           31.000         2013.000  Jan,Apr,Jul,Oct
#
# [14832 rows x 17 columns]

# %%
clean_df.remove_unnamed_cols()

# %%
clean_df.save(name="../data/testing.csv")
